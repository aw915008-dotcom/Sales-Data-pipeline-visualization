# %%
from flask import Flask , request , jsonify
import pyodbc
import pymongo
from pymongo import MongoClient
from bson.objectid import ObjectId
import threading
import time
from datetime import datetime, date
from decimal import Decimal
import requests

# %%
app = Flask(__name__)

# اتصال بالـ MongoDB
client = MongoClient("mongodb://localhost:27017/")
db = client["MyDatabase"]

source_coll = db["RetailCustomerData_Coll"]
target_coll = db["SalesCollection1"]
target_coll = db["TopCustomers"] 
target_coll = db["BestSellingProducts"] 
target_coll = db["BestSellingProductsByBranch"] 
target_coll = db["BranchRevenueComparison"] 
target_coll = db["MonthlySalesTrends"] 
target_coll = db["SeasonalProductDemand"] 
target_coll = db["StockPlanning"]

# %%
# ============================
# 1- API to generate SalesCollection from source data
# ============================
@app.route("/generate_sales_collection", methods=["POST"])
def generate_sales_collection():
    try:
        pipeline = [
            {
                "$group": {
                    "_id": {
                        "CustomerID": "$CustomerID",
                        "CustomerName": "$CustomerName",
                        "PreferredBranch": "$BranchName"
                    },
                    "TotalSpent": {"$sum": "$TotalPrice"},
                    "TotalOrders": {"$addToSet": "$SaleID"},
                    "TopProducts": {
                        "$push": {
                            "ProductName": "$ProductName",
                            "Quantity": "$Quantity"
                        }
                    },
                    "MonthlyPurchases": {
                        "$push": {
                            "Month": {
                                "$dateToString": {"format": "%Y-%m", "date": "$SaleDate"}
                            },
                            "Amount": "$TotalPrice"
                        }
                    }
                }
            },
            {
                "$project": {
                    "_id": 0,
                    "CustomerID": "$_id.CustomerID",
                    "CustomerName": "$_id.CustomerName",
                    "PreferredBranch": "$_id.PreferredBranch",
                    "TotalSpent": 1,
                    "TotalOrders": {"$size": "$TotalOrders"},
                    "TopProducts": 1,
                    "MonthlyPurchases": {
                        "$arrayToObject": {
                            "$map": {
                                "input": "$MonthlyPurchases",
                                "as": "mp",
                                "in": {"k": "$$mp.Month", "v": "$$mp.Amount"}
                            }
                        }
                    }
                }
            },
            {"$out": "SalesCollection1"}
        ]

        # Execute aggregation pipeline
        source_coll.aggregate(pipeline)

        return jsonify({"message": "SalesCollection generated successfully ✅"}), 201
    except Exception as e:
        return jsonify({"error": str(e)}), 500


# ============================
# 2- API to fetch data from SalesCollection
# ============================
@app.route("/get_sales_collection", methods=["GET"])
def get_sales_collection():
    try:
        data = list(target_coll.find({}, {"_id": 0}))
        return jsonify(data), 200
    except Exception as e:
        return jsonify({"error": str(e)}), 500

# %%
# ============================
# API: Generate Top Customers Collection
# ============================
@app.route("/generate_top_customers", methods=["POST"])
def generate_top_customers():
    try:
        pipeline = [
            {
                "$group": {
                    "_id": {
                        "CustomerID": "$CustomerID",
                        "CustomerName": "$CustomerName"
                    },
                    "TotalSpent": {"$sum": "$TotalPrice"}
                }
            },
            {
                "$project": {
                    "_id": 0,
                    "CustomerID": "$_id.CustomerID",
                    "CustomerName": "$_id.CustomerName",
                    "TotalSpent": 1
                }
            },
            {"$sort": {"TotalSpent": -1}},   # Sort descending
            {"$limit": 5},                   # Top 5
            {"$out": "TopCustomers"}         # Save result in new collection
        ]

        source_coll.aggregate(pipeline)
        return jsonify({"message": "TopCustomers collection created successfully ✅"}), 201

    except Exception as e:
        return jsonify({"error": str(e)}), 500


# ============================
# API: Fetch Top Customers Collection
# ============================
@app.route("/get_top_customers", methods=["GET"])
def get_top_customers():
    try:
        data = list(target_coll.find({}, {"_id": 0}))
        return jsonify(data), 200
    except Exception as e:
        return jsonify({"error": str(e)}), 500

# %%
# ============================
# API: Generate Best-Selling Products Collection
# ============================
@app.route("/generate_best_selling_products", methods=["POST"])
def generate_best_selling_products():
    try:
        pipeline = [
            {
                "$group": {
                    "_id": "$ProductName",
                    "TotalQuantity": {"$sum": "$Quantity"},
                    "TotalRevenue": {"$sum": "$TotalPrice"}
                }
            },
            {
                "$project": {
                    "_id": 0,
                    "ProductName": "$_id",
                    "TotalQuantity": 1,
                    "TotalRevenue": 1
                }
            },
            {"$sort": {"TotalQuantity": -1}},   # Sort by quantity sold (descending)
            {"$limit": 10},                     # Top 10 best-selling products
            {"$out": "BestSellingProducts"}     # Save in new collection
        ]

        source_coll.aggregate(pipeline)
        return jsonify({"message": "BestSellingProducts collection created successfully ✅"}), 201

    except Exception as e:
        return jsonify({"error": str(e)}), 500


# ============================
# API: Fetch Best-Selling Products Collection
# ============================
@app.route("/get_best_selling_products", methods=["GET"])
def get_best_selling_products():
    try:
        data = list(db["BestSellingProducts"].find({}, {"_id": 0}))
        return jsonify(data), 200
    except Exception as e:
        return jsonify({"error": str(e)}), 500

# %%
# ============================
# API: Generate Best-Selling Products by Branch Collection
# ============================
@app.route("/generate_best_selling_products_by_branch", methods=["POST"])
def generate_best_selling_products_by_branch():
    try:
        pipeline = [
            {
                "$group": {
                    "_id": {
                        "BranchName": "$BranchName",
                        "ProductName": "$ProductName"
                    },
                    "TotalQuantity": {"$sum": "$Quantity"},
                    "TotalRevenue": {"$sum": "$TotalPrice"}
                }
            },
            {
                "$project": {
                    "_id": 0,
                    "BranchName": "$_id.BranchName",
                    "ProductName": "$_id.ProductName",
                    "TotalQuantity": 1,
                    "TotalRevenue": 1
                }
            },
            {"$sort": {"BranchName": 1, "TotalQuantity": -1}},  # Sort by branch then quantity
            {"$out": "BestSellingProductsByBranch"}             # Save in new collection
        ]

        source_coll.aggregate(pipeline)
        return jsonify({"message": "BestSellingProductsByBranch collection created successfully ✅"}), 201

    except Exception as e:
        return jsonify({"error": str(e)}), 500


# ============================
# API: Fetch Best-Selling Products by Branch Collection
# ============================
@app.route("/get_best_selling_products_by_branch", methods=["GET"])
def get_best_selling_products_by_branch():
    try:
        data = list(db["BestSellingProductsByBranch"].find({}, {"_id": 0}))
        return jsonify(data), 200
    except Exception as e:
        return jsonify({"error": str(e)}), 500

# %%
# ============================
# API: Generate Branch Revenue Comparison Collection
# ============================
@app.route("/generate_branch_revenue_comparison", methods=["POST"])
def generate_branch_revenue_comparison():
    try:
        pipeline = [
            {
                "$group": {
                    "_id": "$BranchName",
                    "TotalRevenue": {"$sum": "$TotalPrice"}
                }
            },
            {
                "$project": {
                    "_id": 0,
                    "BranchName": "$_id",
                    "TotalRevenue": 1
                }
            },
            {"$sort": {"TotalRevenue": -1}},  
            {"$out": "BranchRevenueComparison"}
        ]

        source_coll.aggregate(pipeline)
        return jsonify({"message": "BranchRevenueComparison collection created successfully ✅"}), 201

    except Exception as e:
        return jsonify({"error": str(e)}), 500


# ============================
# API: Fetch Branch Revenue Comparison Collection
# ============================
@app.route("/get_branch_revenue_comparison", methods=["GET"])
def get_branch_revenue_comparison():
    try:
        data = list(db["BranchRevenueComparison"].find({}, {"_id": 0}))
        return jsonify(data), 200
    except Exception as e:
        return jsonify({"error": str(e)}), 500

# %%
# ============================
# API: Generate Monthly Sales Trends Collection
# ============================
@app.route("/generate_monthly_sales_trends", methods=["POST"])
def generate_monthly_sales_trends():
    try:
        pipeline = [
            {
                "$group": {
                    "_id": {
                        "Month": {"$dateToString": {"format": "%Y-%m", "date": "$SaleDate"}}
                    },
                    "TotalRevenue": {"$sum": "$TotalPrice"}
                }
            },
            {
                "$project": {
                    "_id": 0,
                    "Month": "$_id.Month",
                    "TotalRevenue": 1
                }
            },
            {"$sort": {"Month": 1}},  # ترتيب تصاعدي بالشهور
            {"$out": "MonthlySalesTrends"}  # حفظ النتيجة في كوليكشن جديد
        ]

        source_coll.aggregate(pipeline)
        return jsonify({"message": "MonthlySalesTrends collection created successfully ✅"}), 201

    except Exception as e:
        return jsonify({"error": str(e)}), 500


# ============================
# API: Fetch Monthly Sales Trends Collection
# ============================
@app.route("/get_monthly_sales_trends", methods=["GET"])
def get_monthly_sales_trends():
    try:
        data = list(db["MonthlySalesTrends"].find({}, {"_id": 0}))
        return jsonify(data), 200
    except Exception as e:
        return jsonify({"error": str(e)}), 500

# %%
# ============================
# API: Generate Seasonal Product Demand Collection
# ============================
@app.route("/generate_seasonal_product_demand", methods=["POST"])
def generate_seasonal_product_demand():
    try:
        pipeline = [
            {
                "$group": {
                    "_id": {
                        "Month": {"$dateToString": {"format": "%Y-%m", "date": "$SaleDate"}},
                        "ProductName": "$ProductName"
                    },
                    "TotalQuantity": {"$sum": "$Quantity"},
                    "TotalRevenue": {"$sum": "$TotalPrice"}
                }
            },
            {
                "$project": {
                    "_id": 0,
                    "Month": "$_id.Month",
                    "ProductName": "$_id.ProductName",
                    "TotalQuantity": 1,
                    "TotalRevenue": 1
                }
            },
            {"$sort": {"Month": 1, "TotalQuantity": -1}},
            {"$out": "SeasonalProductDemand"}
        ]

        source_coll.aggregate(pipeline)
        return jsonify({"message": "SeasonalProductDemand collection created successfully ✅"}), 201

    except Exception as e:
        return jsonify({"error": str(e)}), 500


# ============================
# API: Fetch Seasonal Product Demand Collection
# ============================
@app.route("/get_seasonal_product_demand", methods=["GET"])
def get_seasonal_product_demand():
    try:
        data = list(db["SeasonalProductDemand"].find({}, {"_id": 0}))
        return jsonify(data), 200
    except Exception as e:
        return jsonify({"error": str(e)}), 500

# %%
# ============================
# API: Generate Stock Planning Collection
# ============================
@app.route("/generate_stock_planning", methods=["POST"])
def generate_stock_planning():
    try:
        pipeline = [
            {
                "$group": {
                    "_id": {
                        "BranchName": "$BranchName",
                        "ProductName": "$ProductName"
                    },
                    "TotalQuantity": {"$sum": "$Quantity"}
                }
            },
            {
                "$project": {
                    "_id": 0,
                    "BranchName": "$_id.BranchName",
                    "ProductName": "$_id.ProductName",
                    "TotalQuantity": 1
                }
            },
            {"$sort": {"BranchName": 1, "TotalQuantity": -1}},
            {"$out": "StockPlanning"}
        ]

        source_coll.aggregate(pipeline)
        return jsonify({"message": "StockPlanning collection created successfully ✅"}), 201

    except Exception as e:
        return jsonify({"error": str(e)}), 500


# ============================
# API: Fetch Stock Planning Collection
# ============================
@app.route("/get_stock_planning", methods=["GET"])
def get_stock_planning():
    try:
        data = list(db["StockPlanning"].find({}, {"_id": 0}))
        return jsonify(data), 200
    except Exception as e:
        return jsonify({"error": str(e)}), 500

# %%
# Code to Run the Flask API 
def run_flask():
    app.run(port=5000, debug=False, use_reloader=False)

# Code to Run the Flask API in a separate thread in the background  
threading.Thread(target=run_flask).start()
time.sleep(1)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [27/Aug/2025 23:55:08] "POST /generate_sales_collection HTTP/1.1" 201 -
# 127.0.0.1 - - [27/Aug/2025 23:55:08] "GET /get_sales_collection HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Aug/2025 23:55:08] "POST /generate_top_customers HTTP/1.1" 201 -
# 127.0.0.1 - - [27/Aug/2025 23:55:08] "GET /get_top_customers HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Aug/2025 23:55:08] "POST /generate_best_selling_products HTTP/1.1" 201 -
# 127.0.0.1 - - [27/Aug/2025 23:55:08] "GET /get_best_selling_products HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Aug/2025 23:55:08] "POST /generate_best_selling_products_by_branch HTTP/1.1" 201 -
# 127.0.0.1 - - [27/Aug/2025 23:55:08] "GET /get_best_selling_products_by_branch HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Aug/2025 23:55:08] "POST /generate_branch_revenue_comparison HTTP/1.1" 201 -
# 127.0.0.1 - - [27/Aug/2025 23:55:08] "POST /generate_monthly_sales_trends HTTP/1.1" 201 -
# 127.0.0.1 - - [27/Aug/2025 23:55:08] "POST /generate_seasonal_product_demand HTTP/1.1" 201 -
# 127.0.0.1 - - [27/Aug/2025 23:55:08] "POST /generate_stock_planning HTTP/1.1" 201 -
# 127.0.0.1 - - [27/Aug/2025 23:55:08] "GET /get_branch_revenue_comparison HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Aug/2025 23:55:08] "GET /get_monthly_sales_trends HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Aug/2025 23:55:08] "GET /get_seasonal_product_demand HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Aug/2025 23:55:08] "GET /get_stock_planning HTTP/1.1" 200 -

# %%
import requests

url = "http://127.0.0.1:5000/generate_sales_collection"

response = requests.post(url)

print("Status Code:", response.status_code)
print("Response:", response.json())
# Out:
# Status Code: 201
# Response: {'message': 'SalesCollection generated successfully ✅'}

# %%
import requests

url = "http://127.0.0.1:5000/get_sales_collection"

response = requests.get(url)

print("Status Code:", response.status_code)
print("Response:", response.json())
# Out:
# Status Code: 200
# Response: []

# %%
url = "http://127.0.0.1:5000/generate_top_customers"

response = requests.post(url)

print("Status Code:", response.status_code)
print("Response:", response.json())
# Out:
# Status Code: 201
# Response: {'message': 'TopCustomers collection created successfully ✅'}

# %%
url = "http://127.0.0.1:5000/get_top_customers"

response = requests.get(url)

print("Status Code:", response.status_code)
print("Response:", response.json())
# Out:
# Status Code: 200
# Response: []

# %%
url = "http://127.0.0.1:5000/generate_best_selling_products"

response = requests.post(url)

print("Status Code:", response.status_code)
print("Response:", response.json())
# Out:
# Status Code: 201
# Response: {'message': 'BestSellingProducts collection created successfully ✅'}

# %%
url = "http://127.0.0.1:5000/get_best_selling_products"

response = requests.get(url)

print("Status Code:", response.status_code)
print("Response:", response.json())
# Out:
# Status Code: 200
# Response: [{'ProductName': 'Ball', 'TotalQuantity': 184, 'TotalRevenue': 159047.41999999998}, {'ProductName': 'Poor', 'TotalQuantity': 143, 'TotalRevenue': 160964.72999999998}, {'ProductName': 'Price', 'TotalQuantity': 135, 'TotalRevenue': 102053.15000000001}, {'ProductName': 'Kid', 'TotalQuantity': 121, 'TotalRevenue': 148602.14}, {'ProductName': 'Seem', 'TotalQuantity': 120, 'TotalRevenue': 129247.12}, {'ProductName': 'Every', 'TotalQuantity': 119, 'TotalRevenue': 196156.09000000003}, {'ProductName': 'Best', 'TotalQuantity': 117, 'TotalRevenue': 142941.98}, {'ProductName': 'Enter', 'TotalQuantity': 115, 'TotalRevenue': 147427.89}, {'ProductName': 'Heart', 'TotalQuantity': 112, 'TotalRevenue': 111535.08}, {'ProductName': 'Suddenly', 'TotalQuantity': 110, 'TotalRevenue': 180789.98}]

# %%
url = "http://127.0.0.1:5000/generate_best_selling_products_by_branch"

response = requests.post(url)

print("Status Code:", response.status_code)
print("Response:", response.json())
# Out:
# Status Code: 201
# Response: {'message': 'BestSellingProductsByBranch collection created successfully ✅'}

# %%
url = "http://127.0.0.1:5000/get_best_selling_products_by_branch"

response = requests.get(url)

print("Status Code:", response.status_code)
print("Response:", response.json())
# Out:
# Status Code: 200
# Response: [{'BranchName': 'Abbott, Moore and Larson', 'ProductName': 'Paper', 'TotalQuantity': 22, 'TotalRevenue': 6382.42}, {'BranchName': 'Adams Group', 'ProductName': 'Prove', 'TotalQuantity': 36, 'TotalRevenue': 35870.04}, {'BranchName': 'Adams Group', 'ProductName': 'Professional', 'TotalQuantity': 10, 'TotalRevenue': 14442.8}, {'BranchName': 'Adams, Russell and Hardin', 'ProductName': 'Kid', 'TotalQuantity': 24, 'TotalRevenue': 47900.16}, {'BranchName': 'Adams, Russell and Hardin', 'ProductName': 'Exactly', 'TotalQuantity': 7, 'TotalRevenue': 4674.46}, {'BranchName': 'Adams, Russell and Hardin', 'ProductName': 'Instead', 'TotalQuantity': 6, 'TotalRevenue': 11315.7}, {'BranchName': 'Ali PLC', 'ProductName': 'Need', 'TotalQuantity': 36, 'TotalRevenue': 26415.72}, {'BranchName': 'Ali PLC', 'ProductName': 'Fight', 'TotalQuantity': 6, 'TotalRevenue': 1169.28}, {'BranchName': 'Allen-Harris', 'ProductName': 'With', 'TotalQuantity': 12, 'TotalRevenue': 8338.8}, {'BranchName': 'Alvarez, Barrett and Porter', 'ProductName': 'Green', 'TotalQuantity': 40, 'TotalRevenue': 76884.0}, {'BranchName': 'Alvarez, Barrett and Porter', 'ProductName': 'Desk Wooden', 'TotalQuantity': 10, 'TotalRevenue': 10311.8}, {'BranchName': 'Alvarez, Barrett and Porter', 'ProductName': 'Seven', 'TotalQuantity': 3, 'TotalRevenue': 1911.99}, {'BranchName': 'Anderson LLC', 'ProductName': 'Ball', 'TotalQuantity': 32, 'TotalRevenue': 46635.52}, {'BranchName': 'Anderson LLC', 'ProductName': 'The', 'TotalQuantity': 18, 'TotalRevenue': 16342.38}, {'BranchName': 'Anderson Ltd', 'ProductName': 'Suddenly', 'TotalQuantity': 34, 'TotalRevenue': 59110.36}, {'BranchName': 'Anderson Ltd', 'ProductName': 'Page', 'TotalQuantity': 18, 'TotalRevenue': 19810.44}, {'BranchName': 'Anderson Ltd', 'ProductName': 'Generation', 'TotalQuantity': 8, 'TotalRevenue': 7783.36}, {'BranchName': 'Anderson Ltd', 'ProductName': 'Story', 'TotalQuantity': 2, 'TotalRevenue': 2003.78}, {'BranchName': 'Andrews-Montgomery', 'ProductName': 'Analysis', 'TotalQuantity': 20, 'TotalRevenue': 10542.0}, {'BranchName': 'Andrews-Montgomery', 'ProductName': 'Card', 'TotalQuantity': 1, 'TotalRevenue': 658.07}, {'BranchName': 'Armstrong-Franklin', 'ProductName': 'Vote', 'TotalQuantity': 30, 'TotalRevenue': 59142.0}, {'BranchName': 'Avila-Crosby', 'ProductName': 'Necessary', 'TotalQuantity': 40, 'TotalRevenue': 23326.8}, {'BranchName': 'Avila-Crosby', 'ProductName': 'Enter', 'TotalQuantity': 6, 'TotalRevenue': 4192.14}, {'BranchName': 'Baker, Vargas and Sosa', 'ProductName': 'Pay', 'TotalQuantity': 40, 'TotalRevenue': 44767.2}, {'BranchName': 'Baker, Vargas and Sosa', 'ProductName': 'Meeting', 'TotalQuantity': 40, 'TotalRevenue': 1710.0}, {'BranchName': 'Baker-Potts', 'ProductName': 'May', 'TotalQuantity': 26, 'TotalRevenue': 18528.12}, {'BranchName': 'Banks-Page', 'ProductName': 'Factor', 'TotalQuantity': 8, 'TotalRevenue': 15336.0}, {'BranchName': 'Barker, Robinson and Jenkins', 'ProductName': 'Stand', 'TotalQuantity': 16, 'TotalRevenue': 19368.8}, {'BranchName': 'Barnes LLC', 'ProductName': 'Economy', 'TotalQuantity': 8, 'TotalRevenue': 6826.8}, {'BranchName': 'Baxter, Stewart and Powell', 'ProductName': 'Guess', 'TotalQuantity': 40, 'TotalRevenue': 37510.4}, {'BranchName': 'Bennett PLC', 'ProductName': 'Make', 'TotalQuantity': 38, 'TotalRevenue': 58722.92}, {'BranchName': 'Bird, Bush and James', 'ProductName': 'Job', 'TotalQuantity': 14, 'TotalRevenue': 15299.2}, {'BranchName': 'Bird, Bush and James', 'ProductName': 'Read', 'TotalQuantity': 4, 'TotalRevenue': 67.72}, {'BranchName': 'Blanchard Group', 'ProductName': 'World', 'TotalQuantity': 26, 'TotalRevenue': 38006.28}, {'BranchName': 'Blanchard Group', 'ProductName': 'Church', 'TotalQuantity': 15, 'TotalRevenue': 21408.75}, {'BranchName': 'Blanchard, Torres and Osborn', 'ProductName': 'Card', 'TotalQuantity': 34, 'TotalRevenue': 48608.78}, {'BranchName': 'Bowen-Thompson', 'ProductName': 'Speech', 'TotalQuantity': 32, 'TotalRevenue': 32200.96}, {'BranchName' ...

# %%
url = "http://127.0.0.1:5000/generate_branch_revenue_comparison"

response = requests.post(url)

print("Status Code:", response.status_code)
print("Response:", response.json())


url = "http://127.0.0.1:5000/generate_monthly_sales_trends"

response = requests.post(url)

print("Status Code:", response.status_code)
print("Response:", response.json())


url = "http://127.0.0.1:5000/generate_seasonal_product_demand"

response = requests.post(url)

print("Status Code:", response.status_code)
print("Response:", response.json())


url = "http://127.0.0.1:5000/generate_stock_planning"

response = requests.post(url)

print("Status Code:", response.status_code)
print("Response:", response.json())
# Out:
# Status Code: 201
# Response: {'message': 'BranchRevenueComparison collection created successfully ✅'}
# Status Code: 201
# Response: {'message': 'MonthlySalesTrends collection created successfully ✅'}
# Status Code: 201
# Response: {'message': 'SeasonalProductDemand collection created successfully ✅'}
# Status Code: 201
# Response: {'message': 'StockPlanning collection created successfully ✅'}

# %%
url = "http://127.0.0.1:5000/get_branch_revenue_comparison"

response = requests.get(url)

print("Status Code:", response.status_code)
print("Response:", response.json())


url = "http://127.0.0.1:5000/get_monthly_sales_trends"

response = requests.get(url)

print("Status Code:", response.status_code)
print("Response:", response.json())


url = "http://127.0.0.1:5000/get_seasonal_product_demand"

response = requests.get(url)

print("Status Code:", response.status_code)
print("Response:", response.json())


url = "http://127.0.0.1:5000/get_stock_planning"

response = requests.get(url)

print("Status Code:", response.status_code)
print("Response:", response.json())
# Out:
# Status Code: 200
# Response: [{'BranchName': 'Rice Ltd', 'TotalRevenue': 257524.56}, {'BranchName': 'Flores, Griffin and Thompson', 'TotalRevenue': 230370.56}, {'BranchName': 'Villanueva Ltd', 'TotalRevenue': 198518.22}, {'BranchName': 'Vasquez and Sons', 'TotalRevenue': 179681.18}, {'BranchName': 'Sanders PLC', 'TotalRevenue': 166962.74}, {'BranchName': 'Schroeder-Davenport', 'TotalRevenue': 166276.34}, {'BranchName': 'Russell, Church and Huang', 'TotalRevenue': 162406.36000000002}, {'BranchName': 'City Center Branch', 'TotalRevenue': 162376.8}, {'BranchName': 'Taylor, Fleming and Moody', 'TotalRevenue': 160536.1}, {'BranchName': 'Wagner PLC', 'TotalRevenue': 159727.68}, {'BranchName': 'Hicks-Ramirez', 'TotalRevenue': 148698.79}, {'BranchName': 'Sanchez-Ponce', 'TotalRevenue': 148163.14}, {'BranchName': 'Haney Group', 'TotalRevenue': 140461.83}, {'BranchName': 'Chavez-Andrews', 'TotalRevenue': 140004.38}, {'BranchName': 'Kelly-Hall', 'TotalRevenue': 139974.28}, {'BranchName': 'Kim Ltd', 'TotalRevenue': 137508.54}, {'BranchName': 'Maxwell-Miller', 'TotalRevenue': 136891.06}, {'BranchName': 'Gardner Ltd', 'TotalRevenue': 134458.77}, {'BranchName': 'Sherman, Robinson and White', 'TotalRevenue': 126760.92}, {'BranchName': 'Riddle and Sons', 'TotalRevenue': 121107.43}, {'BranchName': 'Smith, Mendoza and Rowland', 'TotalRevenue': 119216.24}, {'BranchName': 'Hammond-Mitchell', 'TotalRevenue': 119150.83}, {'BranchName': 'Reid PLC', 'TotalRevenue': 117324.98}, {'BranchName': 'Thompson LLC', 'TotalRevenue': 116223.66}, {'BranchName': 'Hurst Inc', 'TotalRevenue': 113351.44}, {'BranchName': 'Montgomery-Powell', 'TotalRevenue': 113194.67000000001}, {'BranchName': 'Espinoza, Johnson
20, 'TotalRevenue': 37965.2}, {'Month': '2020-02', 'ProductName': 'Put', 'TotalQuantity': 18, 'TotalRevenue': 27407.88}, {'Month': '2020-02', 'ProductName': 'Once', 'TotalQuantity': 18, 'TotalRevenue': 34525.44}, {'Month': '2020-02', 'ProductName': 'Medical', 'TotalQuantity': 14, 'TotalRevenue': 24218.6}, {'Month': '2020-02', 'ProductName': 'Out', 'TotalQuantity': 11, 'TotalRevenue': 7299.93}, {'Month': '2020-02', 'ProductName': 'Wife', 'TotalQuantity': 8, 'TotalRevenue': 149.44}, {'Month': '2020-02', 'ProductName': 'You', 'TotalQuantity': 6, 'TotalRevenue': 7824.96}, {'Month': '2020-02', 'ProductName': 'Discover', 'TotalQuantity': 6, 'TotalRevenue': 7993.08}, {'Month': '2020-02', 'ProductName': 'Important', 'TotalQuantity': 4, 'TotalRevenue': 4223.4}, {'Month': '2020-02', 'ProductName': 'Fall', 'TotalQuantity': 3, 'TotalRevenue': 5374.92}, {'Month': '2020-03', 'ProductName': 'Seem', 'TotalQuantity': 40, 'TotalRevenue': 62227.2}, {'Month': '2020-03', 'ProductName': 'Realize', 'TotalQuantity': 34, 'TotalRevenue': 60221.82}, {'Month': '2020-03', 'ProductName': 'Medical', 'TotalQuantity': 30, 'TotalRevenue': 21311.4}, {'Month': '2020-03', 'ProductName': 'Between', 'TotalQuantity': 28, 'TotalRevenue': 17743.6}, {'Month': '2020-03', 'ProductName': 'Life', 'TotalQuantity': 24, 'TotalRevenue': 10378.32}, {'Month': '2020-03', 'ProductName': 'School', 'TotalQuantity': 22, 'TotalRevenue': 1008.7}, {'Month': '2020-03', 'ProductName': 'Suddenly', 'TotalQuantity': 18, 'TotalRevenue': 32573.16}, {'Month': '2020-03 ...
# Status Code: 200
# Response: [{'BranchName': 'Abbott, Moore and Larson', 'ProductName': 'Paper', 'TotalQuantity': 22}, {'BranchName': 'Adams Group', 'ProductName': 'Prove', 'TotalQuantity': 36}, {'BranchName': 'Adams Group', 'ProductName': 'Professional', 'TotalQuantity': 10}, {'BranchName': 'Adams, Russell and Hardin', 'ProductName': 'Kid', 'TotalQuantity': 24}, {'BranchName': 'Adams, Russell and Hardin', 'ProductName': 'Exactly', 'TotalQuantity': 7}, {'BranchName': 'Adams, Russell and Hardin', 'ProductName': 'Instead', 'TotalQuantity': 6}, {'BranchName': 'Ali PLC', 'ProductName': 'Need', 'TotalQuantity': 36}, {'BranchName': 'Ali PLC', 'ProductName': 'Fight', 'TotalQuantity': 6}, {'BranchName': 'Allen-Harris', 'ProductName': 'With', 'TotalQuantity': 12}, {'BranchName': 'Alvarez, Barrett and Porter', 'ProductName': 'Green', 'TotalQuantity': 40}, {'BranchName': 'Alvarez, Barrett and Porter', 'ProductName': 'Desk Wooden', 'TotalQuantity': 10}, {'BranchName': 'Alvarez, Barrett and Porter', 'ProductName': 'Seven', 'TotalQuantity': 3}, {'BranchName': 'Anderson LLC', 'ProductName': 'Ball', 'TotalQuantity': 32}, {'BranchName': 'Anderson LLC', 'ProductName': 'The', 'TotalQuantity': 18}, {'BranchName': 'Anderson Ltd', 'ProductName': 'Suddenly', 'TotalQuantity': 34}, {'BranchName': 'Anderson Ltd', 'ProductName': 'Page', 'TotalQuantity': 18}, {'BranchName': 'Anderson Ltd', 'ProductName': 'Generation', 'TotalQuantity': 8}, {'BranchName': 'Anderson Ltd', 'ProductName': 'Story', 'TotalQuantity': 2}, {'BranchName': 'Andrews-Montgomery', 'ProductName': 'Analysis', 'TotalQuantity': 20}, {'BranchName': 'Andrews-Montgomery', 'ProductName': 'Card', 'TotalQuantity': 1}, {'BranchName': 'Armstrong-Franklin', 'ProductName': 'Vote', 'TotalQuantity': 30}, {'BranchName': 'Avila-Crosby', 'ProductName': 'Necessary', 'TotalQuantity': 40}, {'BranchName': 'Avila-Crosby', 'ProductName': 'Enter', 'TotalQuantity': 6}, {'BranchName': 'Baker, Vargas and Sosa', 'ProductName': 'Pay', 'TotalQuantity': 40}, {'BranchName': 'Baker, Vargas and Sosa', 'ProductName': 'Meeting', 'TotalQuantity': 40}, {'BranchName': 'Baker-Potts', 'ProductName': 'May', 'TotalQuantity': 26}, {'BranchName': 'Banks-Page', 'ProductName': 'Factor', 'TotalQuantity': 8}, {'BranchName': 'Barker, Robinson and Jenkins', 'ProductName': 'Stand', 'TotalQuantity': 16}, {'BranchName': 'Barnes LLC', 'ProductName': 'Economy', 'TotalQuantity': 8}, {'BranchName': 'Baxter, Stewart and Powell', 'ProductName': 'Guess', 'TotalQuantity': 40}, {'BranchName': 'Bennett PLC', 'ProductName': 'Make', 'TotalQuantity': 38}, {'BranchName': 'Bird, Bush and James', 'ProductName': 'Job', 'TotalQuantity': 14}, {'BranchName': 'Bird, Bush and James', 'ProductName': 'Read', 'TotalQuantity': 4}, {'BranchName': 'Blanchard Group', 'ProductName': 'World', 'TotalQuantity': 26}, {'BranchName': 'Blanchard Group', 'ProductName': 'Church', 'TotalQuantity': 15}, {'BranchName': 'Blanchard, Torres and Osborn', 'ProductName': 'Card', 'TotalQuantity': 34}, {'BranchName': 'Bowen-Thompson', 'ProductName': 'Speech', 'TotalQuantity': 32}, {'BranchName': 'Bowen-Thompson', 'ProductName': 'Paper', 'TotalQuantity': 18}, {'BranchName': 'Bowen-Thompson', 'ProductName': 'Sell', 'TotalQuantity': 14}, {'BranchName': 'Boyle, Kane and Harris', 'ProductName': 'Meeting', 'TotalQuantity': 18}, {'BranchName': 'Bradshaw, Brooks and Henderson', 'ProductName': 'Born', 'TotalQuantity': 20}, {'BranchName': 'Bradshaw, Brooks and Henderson', 'ProductName': 'Dinner', 'TotalQuantity': 4}, {'BranchName': 'Branch, Hernandez and Vargas', 'ProductName': 'Career', 'TotalQuantity': 32}, {'BranchName': 'Brewer, Thomas and Ford', 'ProductName': 'Meeting', 'TotalQuantity': 34}, {'BranchName': 'Brown LLC', 'ProductName': 'Research', 'TotalQuantity': 14}, {'BranchName': 'Brown LLC', 'ProductName': 'Risk', 'TotalQuantity': 12}, {'BranchName': 'Brown PLC', 'ProductName': 'Charge', 'TotalQuantity': 12}, {'BranchName': 'Brown-Smith', 'ProductName': 'Reveal', 'TotalQuantity': 20}, {'BranchName': 'Brown-St ...
